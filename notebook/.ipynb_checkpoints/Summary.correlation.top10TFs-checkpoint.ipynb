# %% [markdown]
# ### Summarize correlation matrices
#
# matrix of experiments (top10 TFs)

# %%
data.dir.id <- "20180222-1400"
data.dir <- file.path("../data", data.dir.id)
all.matrix <- readRDS(file.path(data.dir, "rds", "all.matrix.rds"))
head(all.matrix)
# Out:
#            DRX013180   DRX013190   DRX013200   DRX013210  ERX1149048
# DRX013180  1.000000000 0.084502927 0.086649709 0.04364037 0.001818952
# DRX013190  0.084502927 1.000000000 0.077017746 0.04030838 0.001376185
# DRX013200  0.086649709 0.077017746 1.000000000 0.05773544 0.003612663
# DRX013210  0.043640373 0.040308382 0.057735437 1.00000000 0.020961170
# ERX1149048 0.001818952 0.001376185 0.003612663 0.02096117 1.000000000
# ERX371660  0.001846300 0.001408053 0.003629294 0.02538900 0.136548398
#            ERX371660   ERX371664   ERX371668   ERX371671   ERX371675    ⋯
# DRX013180  0.001846300 0.001617816 0.002029537 0.002316527 0.0015315180 ⋯
# DRX013190  0.001408053 0.001244093 0.001548553 0.001512141 0.0008069931 ⋯
# DRX013200  0.003629294 0.003145475 0.004534249 0.003380099 0.0037695736 ⋯
# DRX013210  0.025388999 0.017144015 0.015028511 0.029004860 0.0264990227 ⋯
# ERX1149048 0.136548398 0.132484422 0.084334516 0.143037431 0.1680607557 ⋯
# ERX371660  1.000000000 0.132484282 0.098398898 0.207655260 0.1935308303 ⋯
#            SRX026721   SRX028634   SRX028635   SRX039137   SRX054571
# DRX013180  0.001804954 0.002040768 0.002740974 0.002962107 0.012219234
# DRX013190  0.001800092 0.002245308 0.002154767 0.001751341 0.006334825
# DRX013200  0.004187534 0.002650783 0.002686414 0.001848927 0.009346665
# DRX013210  0.032150621 0.001960860 0.001593495 0.008716720 0.002723358
# ERX1149048 0.140238901 0.001586681 0.002675196 0.030336542 0.001675852
# ERX371660  0.165742723 0.001609326 0.001796383 0.029077502 0.002998674
#            SRX054572   SRX054573    SRX080130   SRX080131   SRX080135
# DRX013180  0.004968395 0.0012315413 0.002523693 0.002213656 0.003031208
# DRX013190  0.003870215 0.0010211031 0.002227063 0.003422598 0.003464882
# DRX013200  0.004590364 0.0009852376 0.006172343 0.004795838 0.004559915
# DRX013210  0.001064401 0.0019370615 0.029501810 0.033482164 0.033980603
# ERX1149048 0.003405635 0.0091553943 0.088078512 0.125790554 0.037718851
# ERX371660  0.004157218 0.0091584702 0.096092103 0.125790902 0.046115775

# %% [markdown]
# ### Load metadata

# %%
metadata.path <- file.path(data.dir, "metadata", "exps_downloaded.reduced.tsv")
metadata <- read.delim(metadata.path, header=F)
head(metadata)
# Out:
#   V1         V2   V3              V4
# 1 DRX013180  CTCF Digestive tract DLD-1
# 2 DRX013190  CTCF Kidney          293
# 3 DRX013200  CTCF Uterus          HeLa
# 4 DRX013210  CTCF Breast          MCF-7
# 5 ERX1149048 CTCF Blood           HEL 92.1.7
# 6 SRX003937  ESR1 Breast          MCF-7

# %%
tfs.list.path <- file.path(data.dir, "metadata", "tfs_downloaded.txt")
tfs.vec <- readLines(tfs.list.path)
head(tfs.vec)
# Out:
# [1] "CTCF"         "ESR1"         "AR"           "Epitope tags" "BRD4"
# [6] "GFP"

# %% [markdown]
# ### Distribution of correlation coefficient in each TF

# %%
library(reshape2)
library(ggplot2)

# %%
head(melt(all.matrix))
# Out:
#   Var1       Var2      value
# 1 DRX013180  DRX013180 1.000000000
# 2 DRX013190  DRX013180 0.084502927
# 3 DRX013200  DRX013180 0.086649709
# 4 DRX013210  DRX013180 0.043640373
# 5 ERX1149048 DRX013180 0.001818952
# 6 ERX371660  DRX013180 0.001846300

# %%
mat.melt <- melt(all.matrix)
mat.melt <- mat.melt[mat.melt$value != 1,]

# %%
ggplot(mat.melt, aes(as.factor(Var1), value)) + geom_boxplot() + theme_bw() + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %%
colnames(mat.melt) <- c("expid", "against", "value")
colnames(metadata) <- c("expid", "antigen", "cellTypeClass", "CellType")
mat.md <- merge(mat.melt, metadata, by="expid")
head(mat.md)
# Out:
#   expid     against   value       antigen cellTypeClass   CellType
# 1 DRX013180 ERX371664 0.001617816 CTCF    Digestive tract DLD-1
# 2 DRX013180 SRX017864 0.003753680 CTCF    Digestive tract DLD-1
# 3 DRX013180 ERX371671 0.002316527 CTCF    Digestive tract DLD-1
# 4 DRX013180 SRX039137 0.002962107 CTCF    Digestive tract DLD-1
# 5 DRX013180 SRX054573 0.001231541 CTCF    Digestive tract DLD-1
# 6 DRX013180 SRX011574 0.002041761 CTCF    Digestive tract DLD-1

# %%
p <- ggplot(mat.md, aes(as.factor(expid), value))
p <- p + geom_boxplot(aes(colour=antigen))
p <- p + theme_bw()
p <- p + theme(axis.text.x = element_text(angle = 45, hjust = 1))
p
# Out:
# plot without title

# %%
p <- ggplot(mat.md, aes(as.factor(antigen), value))
p <- p + geom_boxplot()
p <- p + theme_bw()
p <- p + theme(axis.text.x = element_text(angle = 45, hjust = 1))
p
# Out:
# plot without title
